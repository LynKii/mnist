# %% [markdown]
# # 入门｜深度学习实战2：改进上篇的MLP

# %%
# 读写csv
import pandas as pd
# 借助sklearn的StratifiedShuffleSplit进行分层抽样
from sklearn.model_selection import StratifiedShuffleSplit
# 导入Keras
from tensorflow import keras
import numpy as np

# %%
# 读取训练集
data = pd.read_csv('train.csv')
# 读取测试集
test = pd.read_csv('test.csv')

# %%
# 使用StratifiedShuffleSplit类进行分层抽样
split = StratifiedShuffleSplit(n_splits=1, test_size=0.1, random_state=42)

# 按label属性进行划分并生成训练集和验证集
for train_index, valid_index in split.split(data, data['label']):
    train = data.loc[train_index]
    valid = data.loc[valid_index]

# %%
# 划分样本与标签
train_X = train.drop(['label'], axis=1)
train_Y = train['label']

# 验证集也划分一下
valid_X = valid.drop(['label'], axis=1)
valid_Y = valid['label']

# %%
# 基础模型参照，2隐藏层
model1 = keras.models.Sequential([
    keras.layers.InputLayer(input_shape=[784]),
    keras.layers.Dense(300, activation='relu'),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])
# Out:
# 2022-01-20 23:40:54.253403: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-20 23:40:54.257237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-20 23:40:54.257665: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-20 23:40:54.258520: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-20 23:40:54.259121: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-20 23:40:54.259571: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-20 23:40:54.259999: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-20 23:40:54.497349: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-20 23:40:54.497789: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-20 23:40:54.498198: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-20 23:40:54.498585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10231 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# 编译模型
model1.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=keras.optimizers.SGD(learning_rate=0.0001),
    metrics=['accuracy']
)

# 保存最佳模型
checkpoint = keras.callbacks.ModelCheckpoint('model1_best.h5',
                                             save_best_only=True)

# 实现早停
early_stop = keras.callbacks.EarlyStopping(patience=2, monitor='accuracy',
                                           min_delta=0.005,
                                           restore_best_weights=True)

# 训练
history = model1.fit(train_X, train_Y, epochs=100,
                     validation_data=(valid_X, valid_Y),
                     callbacks=[checkpoint, early_stop],
                     batch_size=32)
# Out:
# Epoch 1/100
#  194/1182 [===>..........................] - ETA: 0s - loss: 13.3061 - accuracy: 0.6551
# 2022-01-20 23:40:55.384763: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 1182/1182 [==============================] - 2s 906us/step - loss: 5.0427 - accuracy: 0.8146 - val_loss: 2.1942 - val_accuracy: 0.8726
# Epoch 2/100
# 1182/1182 [==============================] - 1s 821us/step - loss: 1.6007 - accuracy: 0.8953 - val_loss: 1.5211 - val_accuracy: 0.8905
# Epoch 3/100
# 1182/1182 [==============================] - 1s 817us/step - loss: 1.0662 - accuracy: 0.9141 - val_loss: 1.2418 - val_accuracy: 0.9045
# Epoch 4/100
# 1182/1182 [==============================] - 1s 820us/step - loss: 0.7797 - accuracy: 0.9262 - val_loss: 1.0960 - val_accuracy: 0.9102
# Epoch 5/100
# 1182/1182 [==============================] - 1s 814us/step - loss: 0.6067 - accuracy: 0.9359 - val_loss: 0.9698 - val_accuracy: 0.9148
# Epoch 6/100
# 1182/1182 [==============================] - 1s 818us/step - loss: 0.4886 - accuracy: 0.9443 - val_loss: 0.9348 - val_accuracy: 0.9171
# Epoch 7/100
# 1182/1182 [==============================] - 1s 822us/step - loss: 0.4016 - accuracy: 0.9507 - val_loss: 0.8699 - val_accuracy: 0.9179
# Epoch 8/100
# 1182/1182 [==============================] - 1s 810us/step - loss: 0.3387 - accuracy: 0.9549 - val_loss: 0.8302 - val_accuracy: 0.9183
# Epoch 9/100
# 1182/1182 [==============================] - 1s 815us/step - loss: 0.2865 - accuracy: 0.9603 - val_loss: 0.8060 - val_accuracy: 0.9195
# Epoch 10/100
# 1182/1182 [==============================] - 1s 820us/step - loss: 0.2426 - accuracy: 0.9642 - val_loss: 0.7829 - val_accuracy: 0.9219
# Epoch 11/100
# 1182/1182 [==============================] - 1s 827us/step - loss: 0.2114 - accuracy: 0.9681 - val_loss: 0.7732 - val_accuracy: 0.9219
# Epoch 12/100
# 1182/1182 [==============================] - 1s 819us/step - loss: 0.1830 - accuracy: 0.9704 - val_loss: 0.7547 - val_accuracy: 0.9238
# Epoch 13/100
# 1182/1182 [==============================] - 1s 810us/step - loss: 0.1589 - accuracy: 0.9740 - val_loss: 0.7997 - val_accuracy: 0.9200
# Epoch 14/100
# 1182/1182 [==============================] - 1s 817us/step - loss: 0.1416 - accuracy: 0.9761 - val_loss: 0.7384 - val_accuracy: 0.9238
# Epoch 15/100
# 1182/1182 [==============================] - 1s 818us/step - loss: 0.1240 - accuracy: 0.9792 - val_loss: 0.7259 - val_accuracy: 0.9257
# Epoch 16/100
# 1182/1182 [==============================] - 1s 814us/step - loss: 0.1085 - accuracy: 0.9820 - val_loss: 0.7095 - val_accuracy: 0.9262
# Epoch 17/100
# 1182/1182 [==============================] - 1s 821us/step - loss: 0.0976 - accuracy: 0.9831 - val_loss: 0.6979 - val_accuracy: 0.9255
# Epoch 18/100
# 1182/1182 [==============================] - 1s 810us/step - loss: 0.0868 - accuracy: 0.9842 - val_loss: 0.6969 - val_accuracy: 0.9269
# Epoch 19/100
# 1182/1182 [==============================] - 1s 815us/step - loss: 0.0778 - accuracy: 0.9869 - val_loss: 0.6946 - val_accuracy: 0.9269
# Epoch 20/100
# 1182/1182 [==============================] - 1s 820us/step - loss: 0.0694 - accuracy: 0.9879 - val_loss: 0.6978 - val_accuracy: 0.9264
# Epoch 21/100
# 1182/1182 [==============================] - 1s 807us/step - loss: 0.0615 - accuracy: 0.9889 - val_loss: 0.6875 - val_accuracy: 0.9288
# Epoch 22/100
# 1182/1182 [==============================] - 1s 808us/step - loss: 0.0555 - accuracy: 0.9902 - val_loss: 0.6767 - val_accuracy: 0.9290
# Epoch 23/100
# 1182/1182 [==============================] - 1s 820us/step - loss: 0.0497 - accuracy: 0.9919 - val_loss: 0.6716 - val_accuracy: 0.9267
# Epoch 24/100
# 1182/1182 [==============================] - 1s 804us/step - loss: 0.0450 - accuracy: 0.9919 - val_loss: 0.6733 - val_accuracy: 0.9281
# Epoch 25/100
# 1182/1182 [==============================] - 1s 820us/step - loss: 0.0409 - accuracy: 0.9932 - val_loss: 0.6641 - val_accuracy: 0.9290
# Epoch 26/100
# 1182/1182 [==============================] - 1s 824us/step - loss: 0.0364 - accuracy: 0.9940 - val_loss: 0.6604 - val_accuracy: 0.9283
# Epoch 27/100
# 1182/1182 [==============================] - 1s 822us/step - loss: 0.0333 - accuracy: 0.9943 - val_loss: 0.6584 - val_accuracy: 0.9290
# Epoch 28/100
# 1182/1182 [==============================] - 1s 819us/step - loss: 0.0302 - accuracy: 0.9948 - val_loss: 0.6614 - val_accuracy: 0.9286
# Epoch 29/100
# 1182/1182 [==============================] - 1s 814us/step - loss: 0.0272 - accuracy: 0.9958 - val_loss: 0.6552 - val_accuracy: 0.9300
# Epoch 30/100
# 1182/1182 [==============================] - 1s 823us/step - loss: 0.0248 - accuracy: 0.9958 - val_loss: 0.6479 - val_accuracy: 0.9290
# Epoch 31/100
# 1182/1182 [==============================] - 1s 808us/step - loss: 0.0224 - accuracy: 0.9967 - val_loss: 0.6591 - val_accuracy: 0.9286
# Epoch 32/100
# 1182/1182 [==============================] - 1s 814us/step - loss: 0.0206 - accuracy: 0.9969 - val_loss: 0.6464 - val_accuracy: 0.9300
# Epoch 33/100
# 1182/1182 [==============================] - 1s 820us/step - loss: 0.0186 - accuracy: 0.9976 - val_loss: 0.6450 - val_accuracy: 0.9314
# Epoch 34/100
# 1182/1182 [==============================] - 1s 812us/step - loss: 0.0171 - accuracy: 0.9977 - val_loss: 0.6420 - val_accuracy: 0.9312
# Epoch 35/100
# 1182/1182 [==============================] - 1s 818us/step - loss: 0.0159 - accuracy: 0.9980 - val_loss: 0.6407 - val_accuracy: 0.9319
# Epoch 36/100
# 1182/1182 [==============================] - 1s 798us/step - loss: 0.0146 - accuracy: 0.9982 - val_loss: 0.6424 - val_accuracy: 0.9324
# Epoch 37/100
# 1182/1182 [==============================] - 1s 807us/step - loss: 0.0135 - accuracy: 0.9983 - val_loss: 0.6456 - val_accuracy: 0.9300
# Epoch 38/100
# 1182/1182 [==============================] - 1s 817us/step - loss: 0.0126 - accuracy: 0.9985 - val_loss: 0.6382 - val_accuracy: 0.9331
# Epoch 39/100
# 1182/1182 [==============================] - 1s 811us/step - loss: 0.0115 - accuracy: 0.9986 - val_loss: 0.6379 - val_accuracy: 0.9336
# Epoch 40/100
# 1182/1182 [==============================] - 1s 814us/step - loss: 0.0108 - accuracy: 0.9989 - val_loss: 0.6368 - val_accuracy: 0.9319
# Epoch 41/100
# 1182/1182 [==============================] - 1s 815us/step - loss: 0.0101 - accuracy: 0.9990 - val_loss: 0.6402 - val_accuracy: 0.9312
# Epoch 42/100
# 1182/1182 [==============================] - 1s 812us/step - loss: 0.0096 - accuracy: 0.9989 - val_loss: 0.6401 - val_accuracy: 0.9314
# Epoch 43/100
# 1182/1182 [==============================] - 1s 811us/step - loss: 0.0089 - accuracy: 0.9991 - val_loss: 0.6382 - val_accuracy: 0.9321
# Epoch 44/100
# 1182/1182 [==============================] - 1s 797us/step - loss: 0.0084 - accuracy: 0.9992 - val_loss: 0.6381 - val_accuracy: 0.9321
# Epoch 45/100
# 1182/1182 [==============================] - 1s 805us/step - loss: 0.0078 - accuracy: 0.9993 - val_loss: 0.6360 - val_accuracy: 0.9333
# Epoch 46/100
# 1182/1182 [==============================] - 1s 818us/step - loss: 0.0074 - accuracy: 0.9993 - val_loss: 0.6365 - val_accuracy: 0.9340
# Epoch 47/100
# 1182/1182 [==============================] - 1s 813us/step - loss: 0.0069 - accuracy: 0.9995 - val_loss: 0.6385 - val_accuracy: 0.9321
# Epoch 48/100
# 1182/1182 [==============================] - 1s 821us/step - loss: 0.0065 - accuracy: 0.9994 - val_loss: 0.6350 - val_accuracy: 0.9336
# Epoch 49/100
# 1182/1182 [==============================] - 1s 803us/step - loss: 0.0061 - accuracy: 0.9995 - val_loss: 0.6407 - val_accuracy: 0.9321
# Epoch 50/100
# 1182/1182 [==============================] - 1s 818us/step - loss: 0.0058 - accuracy: 0.9996 - val_loss: 0.6330 - val_accuracy: 0.9336
# Epoch 51/100
# 1182/1182 [==============================] - 1s 802us/step - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.6346 - val_accuracy: 0.9336

# %%
# 模型2
model2 = keras.models.Sequential([
    keras.layers.InputLayer(input_shape=[784]),
    keras.layers.Dense(600, activation='relu'),
    keras.layers.Dense(500, activation='relu'),
    keras.layers.Dense(400, activation='relu'),
    keras.layers.Dense(300, activation='relu'),
    keras.layers.Dense(200, activation='relu'),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
# 编译模型
model2.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=keras.optimizers.SGD(learning_rate=0.0001),
    metrics=['accuracy']
)

# 保存最佳模型
checkpoint = keras.callbacks.ModelCheckpoint('model2_best.h5',
                                             save_best_only=True)

# 实现早停
early_stop = keras.callbacks.EarlyStopping(patience=10, monitor='accuracy',
                                           min_delta=0.001,
                                           restore_best_weights=True)

# 训练
history = model2.fit(train_X, train_Y, epochs=100,
                     validation_data=(valid_X, valid_Y),
                     callbacks=[checkpoint, early_stop],
                     batch_size=32)
# Out:
# Epoch 1/100
# 1182/1182 [==============================] - 2s 1ms/step - loss: 1.4640 - accuracy: 0.7439 - val_loss: 0.7861 - val_accuracy: 0.8217
# Epoch 2/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.5250 - accuracy: 0.8709 - val_loss: 0.5148 - val_accuracy: 0.8717
# Epoch 3/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.3753 - accuracy: 0.9005 - val_loss: 0.4452 - val_accuracy: 0.8883
# Epoch 4/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.2957 - accuracy: 0.9189 - val_loss: 0.4052 - val_accuracy: 0.8960
# Epoch 5/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.2469 - accuracy: 0.9306 - val_loss: 0.3674 - val_accuracy: 0.9024
# Epoch 6/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.2070 - accuracy: 0.9405 - val_loss: 0.3467 - val_accuracy: 0.9045
# Epoch 7/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.1787 - accuracy: 0.9481 - val_loss: 0.3258 - val_accuracy: 0.9110
# Epoch 8/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.1571 - accuracy: 0.9546 - val_loss: 0.3166 - val_accuracy: 0.9171
# Epoch 9/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.1384 - accuracy: 0.9606 - val_loss: 0.3063 - val_accuracy: 0.9167
# Epoch 10/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.1227 - accuracy: 0.9652 - val_loss: 0.2963 - val_accuracy: 0.9207
# Epoch 11/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.1104 - accuracy: 0.9698 - val_loss: 0.2887 - val_accuracy: 0.9226
# Epoch 12/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0994 - accuracy: 0.9728 - val_loss: 0.2845 - val_accuracy: 0.9248
# Epoch 13/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0900 - accuracy: 0.9755 - val_loss: 0.2776 - val_accuracy: 0.9269
# Epoch 14/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0818 - accuracy: 0.9783 - val_loss: 0.2773 - val_accuracy: 0.9279
# Epoch 15/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0747 - accuracy: 0.9815 - val_loss: 0.2742 - val_accuracy: 0.9276
# Epoch 16/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0682 - accuracy: 0.9835 - val_loss: 0.2715 - val_accuracy: 0.9295
# Epoch 17/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0628 - accuracy: 0.9847 - val_loss: 0.2697 - val_accuracy: 0.9300
# Epoch 18/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0578 - accuracy: 0.9869 - val_loss: 0.2665 - val_accuracy: 0.9317
# Epoch 19/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0532 - accuracy: 0.9876 - val_loss: 0.2661 - val_accuracy: 0.9321
# Epoch 20/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0491 - accuracy: 0.9895 - val_loss: 0.2628 - val_accuracy: 0.9317
# Epoch 21/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0456 - accuracy: 0.9902 - val_loss: 0.2664 - val_accuracy: 0.9329
# Epoch 22/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0421 - accuracy: 0.9916 - val_loss: 0.2600 - val_accuracy: 0.9331
# Epoch 23/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0390 - accuracy: 0.9923 - val_loss: 0.2632 - val_accuracy: 0.9345
# Epoch 24/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0366 - accuracy: 0.9929 - val_loss: 0.2615 - val_accuracy: 0.9350
# Epoch 25/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0340 - accuracy: 0.9938 - val_loss: 0.2572 - val_accuracy: 0.9360
# Epoch 26/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0317 - accuracy: 0.9946 - val_loss: 0.2571 - val_accuracy: 0.9364
# Epoch 27/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0297 - accuracy: 0.9954 - val_loss: 0.2578 - val_accuracy: 0.9369
# Epoch 28/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0279 - accuracy: 0.9957 - val_loss: 0.2565 - val_accuracy: 0.9367
# Epoch 29/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0261 - accuracy: 0.9962 - val_loss: 0.2554 - val_accuracy: 0.9383
# Epoch 30/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0246 - accuracy: 0.9963 - val_loss: 0.2552 - val_accuracy: 0.9381
# Epoch 31/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0232 - accuracy: 0.9969 - val_loss: 0.2549 - val_accuracy: 0.9390
# Epoch 32/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0218 - accuracy: 0.9972 - val_loss: 0.2533 - val_accuracy: 0.9393
# Epoch 33/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0206 - accuracy: 0.9976 - val_loss: 0.2573 - val_accuracy: 0.9386
# Epoch 34/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0195 - accuracy: 0.9978 - val_loss: 0.2533 - val_accuracy: 0.9388
# Epoch 35/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0184 - accuracy: 0.9980 - val_loss: 0.2538 - val_accuracy: 0.9405
# Epoch 36/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0175 - accuracy: 0.9982 - val_loss: 0.2537 - val_accuracy: 0.9405
# Epoch 37/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0166 - accuracy: 0.9985 - val_loss: 0.2545 - val_accuracy: 0.9402
# Epoch 38/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0158 - accuracy: 0.9986 - val_loss: 0.2529 - val_accuracy: 0.9398
# Epoch 39/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0150 - accuracy: 0.9988 - val_loss: 0.2550 - val_accuracy: 0.9410
# Epoch 40/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0144 - accuracy: 0.9990 - val_loss: 0.2529 - val_accuracy: 0.9402
# Epoch 41/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0137 - accuracy: 0.9990 - val_loss: 0.2539 - val_accuracy: 0.9417
# Epoch 42/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0130 - accuracy: 0.9991 - val_loss: 0.2533 - val_accuracy: 0.9417
# Epoch 43/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0125 - accuracy: 0.9992 - val_loss: 0.2545 - val_accuracy: 0.9402
# Epoch 44/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0120 - accuracy: 0.9994 - val_loss: 0.2530 - val_accuracy: 0.9410
# Epoch 45/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0115 - accuracy: 0.9994 - val_loss: 0.2540 - val_accuracy: 0.9417
# Epoch 46/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0110 - accuracy: 0.9994 - val_loss: 0.2527 - val_accuracy: 0.9419
# Epoch 47/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0106 - accuracy: 0.9995 - val_loss: 0.2525 - val_accuracy: 0.9419
# Epoch 48/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0102 - accuracy: 0.9994 - val_loss: 0.2531 - val_accuracy: 0.9417
# Epoch 49/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0098 - accuracy: 0.9995 - val_loss: 0.2518 - val_accuracy: 0.9421
# Epoch 50/100
# 1182/1182 [==============================] - 1s 1ms/step - loss: 0.0095 - accuracy: 0.9996 - val_loss: 0.2532 - val_accuracy: 0.9424

# %%
model1_best = keras.models.load_model('model1_best.h5')

model1_results = model1_best.predict(test)

# 转换格式
model1_results = np.argmax(model1_results, axis=1)
model1_results = pd.Series(model1_results, name='Label')

# 生成预测文件
model1_submission = pd.concat([pd.Series(range(1, 28001), name="ImageId"),
                               model1_results], axis=1)
model1_submission.to_csv('model1_submission.csv', index=False)

# %%
model2_best = keras.models.load_model('model2_best.h5')

model2_results = model2_best.predict(test)

# 转换格式
model2_results = np.argmax(model2_results, axis=1)
model2_results = pd.Series(model2_results, name='Label')

# 生成预测文件
model2_submission = pd.concat([pd.Series(range(1, 28001), name="ImageId"),
                               model1_results], axis=1)
model2_submission.to_csv('model2_submission.csv', index=False)
